# %%
import requests
import pandas as pd

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 1516,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=37.7749295&location=San%5E%25%5E20Francisco%2C%5E%25%5E20CA&longitude=-122.4194155&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1645063349,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE7MF095836',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE7MF095836',
#    'clickoff_url': 'https://www.shift.com/car/c1353270?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 237466807,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/09/44/2021_tesla_model_y-pic-3936141801191104405-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--K7bM74lT--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/09/44/2021_tesla_model_y-pic-3936141801191104405-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$65,950',
#    'price_unformatted': 65950,
#    'mileage': '15,357 Miles',
#    'mileage_unformatted': 15357,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEE7MF095836',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '323643049',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1353270',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1640793845,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB4LF650017',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4LF650017',
#    'clickoff_url': 'https://www.shift.com/car/c1403290?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234321716,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-6641217372375928096-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--odH4v3Ac--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-6641217372375928096-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$48,650',
#    'price_unformatted': 48650,
#    'mileage': '10,645 Miles',
#    'mileage_unformatted': 10645,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB4LF650017',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '320112155',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1403290',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1643559075,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2JF173091',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF173091',
#    'clickoff_url': 'https://www.shift.com/car/c1520451?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 236373664,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/11/40/2018_tesla_model_3-pic-5349695668134513161-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9hJO_698--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/11/40/2018_tesla_model_3-pic-5349695668134513161-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$43,150',
#    'price_unformatted': 43150,
#    'mileage': '35,559 Miles',
#    'mileage_unformatted': 35559,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2JF173091',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '322393597',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1520451',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Mid Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642176600,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB9KF511760',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB9KF511760',
#    'clickoff_url': 'https://www.shift.com/car/c1272784?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235304456,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2019_tesla_model_3-pic-7915060487973289895-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5tH1Y228--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2019_tesla_model_3-pic-7915060487973289895-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$46,300',
#    'price_unformatted': 46300,
#    'mileage': '28,890 Miles',
#    'mileage_unformatted': 28890,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB9KF511760',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321203974',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1272784',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641347716,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EBXLF650345',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXLF650345',
#    'clickoff_url': 'https://www.shift.com/car/c162764?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234690633,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-3797232775774187303-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hDfjik8G--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-3797232775774187303-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$48,950',
#    'price_unformatted': 48950,
#    'mileage': '5,616 Miles',
#    'mileage_unformatted': 5616,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EBXLF650345',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '320503319',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c162764',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1644112806,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA5JF021452',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA5JF021452',
#    'clickoff_url': 'https://www.shift.com/car/c188352?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 236795354,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/18/13/31/2018_tesla_model_3-pic-7844540094270580836-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--nAxYQr6X--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/18/13/31/2018_tesla_model_3-pic-7844540094270580836-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$44,300',
#    'price_unformatted': 44300,
#    'mileage': '25,355 Miles',
#    'mileage_unformatted': 25355,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA5JF021452',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '322882081',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c188352',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642817179,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6JF053892',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF053892',
#    'clickoff_url': 'https://www.shift.com/car/c195777?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235784316,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2018_tesla_model_3-pic-5257318785289483526-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--sdEspXWC--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2018_tesla_model_3-pic-5257318785289483526-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$39,950',
#    'price_unformatted': 39950,
#    'mileage': '56,823 Miles',
#    'mileage_unformatted': 56823,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6JF053892',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321729854',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c195777',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642009757,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8JF061217',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF061217',
#    'clickoff_url': 'https://www.berkshirehathawayautomotive.com/catcher.esl?vin=5YJ3E1EA8JF061217&atc_ownerid=autolist&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235154879,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/13/07/34/2018_tesla_model_3-pic-1708959278347123645-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--geKhe1mO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/13/07/34/2018_tesla_model_3-pic-1708959278347123645-1024x768.jpeg',
#    'lat': 37.6732,
#    'lon': -122.463,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$45,493',
#    'price_unformatted': 45493,
#    'mileage': '17,885 Miles',
#    'mileage_unformatted': 17885,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 7,
#    'dealer_name': 'Serramonte Ford',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA8JF061217',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321025677',
#     'remote_dealer_id': '55246',
#     'dealer_name': 'Serramonte Ford',
#     'remote_sku': 'P4646',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'serramonte_ford',
#     'dealer_uuid': 'c89730bc-a118-49cb-a50b-09c4ad611540',
#     'dealer_group_unique_name': 'berkshire_hathaway_automotive_car_gurus',
#     'dealer_group_uuid': '6edd5326-1c9f-408d-918f-8cb1cd0e2f01'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 229,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641015253,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2KF301508',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF301508',
#    'clickoff_url': 'https://www.carmax.com/car/21915924?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234532173,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21915924/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0xlfPyHw--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21915924/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.69056829597337,
#    'lon': -122.4466776578749,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$45,998',
#    'price_unformatted': 45998,
#    'mileage': '25,139 Miles',
#    'mileage_unformatted': 25139,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 6,
#    'dealer_name': 'CarMax Serramonte - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2KF301508',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA2KF301508',
#     'remote_dealer_id': '6080',
#     'dealer_name': 'CarMax Serramonte',
#     'remote_sku': '21915924',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_serramonte',
#     'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1643386211,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8JF059211',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF059211',
#    'clickoff_url': 'https://www.shift.com/car/c1419320?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 236226684,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/37/2018_tesla_model_3-pic-9119826179625542533-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Sj-EcbP4--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/37/2018_tesla_model_3-pic-9119826179625542533-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,350',
#    'price_unformatted': 42350,
#    'mileage': '39,643 Miles',
#    'mileage_unformatted': 39643,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA8JF059211',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '322243387',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1419320',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1635959165,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6JF010623',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF010623',
#    'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJ3E1EA6JF010623&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 230794948,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/18/00/42/2018_tesla_model_3-pic-7240699439564966012-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--KN7Xnkd---/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/18/00/42/2018_tesla_model_3-pic-7240699439564966012-1024x768.jpeg',
#    'lat': 38.4108,
#    'lon': -122.719,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$45,577',
#    'price_unformatted': 45577,
#    'mileage': '35,118 Miles',
#    'mileage_unformatted': 35118,
#    'city': 'Santa Rosa',
#    'state': 'CA',
#    'distance_from_origin': 46,
#    'dealer_name': 'Lithia Chrysler Jeep Dodge Of Santa Rosa',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6JF010623',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '316091162',
#     'remote_dealer_id': '60398',
#     'dealer_name': 'Lithia Chrysler Jeep Dodge of Santa Rosa',
#     'remote_sku': 'JF010623',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'lithia_chrysler_jeep_dodgeof_santa_rosa',
#     'dealer_uuid': '854da0e9-8c99-480f-a288-6a3905318ae0',
#     'dealer_group_unique_name': 'lithia_cargurus',
#     'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 229,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1644024604,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA0MF001422',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0MF001422',
#    'clickoff_url': 'https://www.carmax.com/car/21669423?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 236729090,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21669423/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tA-sZLSi--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21669423/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 38.27872113250454,
#    'lon': -122.0043812304184,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$50,998',
#    'price_unformatted': 50998,
#    'mileage': '3,342 Miles',
#    'mileage_unformatted': 3342,
#    'city': 'Fairfield',
#    'state': 'CA',
#    'distance_from_origin': 41,
#    'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA0MF001422',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA0MF001422',
#     'remote_dealer_id': '6048',
#     'dealer_name': 'CarMax Fairfield',
#     'remote_sku': '21669423',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fairfield',
#     'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1645114451,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB7KF387794',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7KF387794',
#    'clickoff_url': 'https://www.shift.com/car/c130527?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 237506693,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/17/01/15/2019_tesla_model_3-pic-3566458169498854992-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--s8W_cxoO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/17/01/15/2019_tesla_model_3-pic-3566458169498854992-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$47,950',
#    'price_unformatted': 47950,
#    'mileage': '39,849 Miles',
#    'mileage_unformatted': 39849,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB7KF387794',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '323677089',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c130527',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642052722,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E47JF263600',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E47JF263600',
#    'clickoff_url': 'https://www.carmax.com/car/21359590?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235194108,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21359590/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--BxM2JJml--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21359590/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.69056829597337,
#    'lon': -122.4466776578749,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$82,998',
#    'price_unformatted': 82998,
#    'mileage': '29,792 Miles',
#    'mileage_unformatted': 29792,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 6,
#    'dealer_name': 'CarMax Serramonte - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJSA1E47JF263600',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJSA1E47JF263600',
#     'remote_dealer_id': '6080',
#     'dealer_name': 'CarMax Serramonte',
#     'remote_sku': '21359590',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_serramonte',
#     'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'P100D',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1643126974,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA9LF808097',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA9LF808097',
#    'clickoff_url': 'https://www.carmax.com/car/22101530?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235965535,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22101530/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4AZtUTNy--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22101530/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.69056829597337,
#    'lon': -122.4466776578749,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$44,998',
#    'price_unformatted': 44998,
#    'mileage': '29,579 Miles',
#    'mileage_unformatted': 29579,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 6,
#    'dealer_name': 'CarMax Serramonte - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA9LF808097',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA9LF808097',
#     'remote_dealer_id': '6080',
#     'dealer_name': 'CarMax Serramonte',
#     'remote_sku': '22101530',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_serramonte',
#     'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1643220039,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB0JF132533',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB0JF132533',
#    'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJ3E1EB0JF132533&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 236072232,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/09/01/28/2018_tesla_model_3-pic-2872840234416838499-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--QblbS7a8--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/09/01/28/2018_tesla_model_3-pic-2872840234416838499-1024x768.jpeg',
#    'lat': 38.4108,
#    'lon': -122.719,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$44,721',
#    'price_unformatted': 44721,
#    'mileage': '51,372 Miles',
#    'mileage_unformatted': 51372,
#    'city': 'Santa Rosa',
#    'state': 'CA',
#    'distance_from_origin': 46,
#    'dealer_name': 'Lithia Chrysler Jeep Dodge Of Santa Rosa',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB0JF132533',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '322045837',
#     'remote_dealer_id': '60398',
#     'dealer_name': 'Lithia Chrysler Jeep Dodge of Santa Rosa',
#     'remote_sku': 'JF132533',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'lithia_chrysler_jeep_dodgeof_santa_rosa',
#     'dealer_uuid': '854da0e9-8c99-480f-a288-6a3905318ae0',
#     'dealer_group_unique_name': 'lithia_cargurus',
#     'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 229,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1645063349,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB1LF628654',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB1LF628654',
#    'clickoff_url': 'https://www.shift.com/car/c154612?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 237466804,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/37/2020_tesla_model_3-pic-1975125474396053237-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--FsiAzq8a--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/37/2020_tesla_model_3-pic-1975125474396053237-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$52,950',
#    'price_unformatted': 52950,
#    'mileage': '11,614 Miles',
#    'mileage_unformatted': 11614,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB1LF628654',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '323643045',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c154612',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1643818164,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEEXMF187815',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEEXMF187815',
#    'clickoff_url': 'https://www.shift.com/car/c111679?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 236537076,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2021_tesla_model_y-pic-4665260296460361596-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--u5oYZ-LK--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2021_tesla_model_y-pic-4665260296460361596-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$63,950',
#    'price_unformatted': 63950,
#    'mileage': '8,950 Miles',
#    'mileage_unformatted': 8950,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEEXMF187815',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '320932984',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c111679',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1643854241,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB8LF647895',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8LF647895',
#    'clickoff_url': 'https://www.shift.com/car/c177818?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 236587326,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/12/39/2020_tesla_model_3-pic-8319363011430771450-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qGmPIrm1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/12/39/2020_tesla_model_3-pic-8319363011430771450-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$49,950',
#    'price_unformatted': 49950,
#    'mileage': '16,761 Miles',
#    'mileage_unformatted': 16761,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB8LF647895',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '322634336',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c177818',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1644942506,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E42FF105222',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E42FF105222',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 237350389,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/14/22/18/2015_tesla_model_s-pic-5088634327951041336-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--zb7sK_jO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/14/22/18/2015_tesla_model_s-pic-5088634327951041336-1024x768.jpeg',
#    'lat': 37.6612,
#    'lon': -122.075,
#    'year': 2015,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$55,991',
#    'price_unformatted': 55991,
#    'mileage': '36,459 Miles',
#    'mileage_unformatted': 36459,
#    'city': 'Hayward',
#    'state': 'CA',
#    'distance_from_origin': 20,
#    'dealer_name': 'AutoNation Toyota Hayward',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJSA1E42FF105222',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '323512089',
#     'remote_dealer_id': '288154',
#     'dealer_name': 'AutoNation Toyota Hayward',
#     'remote_sku': 'FF105222',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'autonation_toyota_hayward',
#     'dealer_uuid': '2cf0bdbe-9dca-454f-bb9a-7f0522880c1c',
#     'dealer_group_unique_name': 'autonation_cargurus',
#     'dealer_group_uuid': '50f624ea-bcec-433b-b6a8-8fa8086d7ab7'},
#    'trim': 'P85D',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+y#vin=5YJYGDEE7MF095836"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--K7bM74lT--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/09/44/2021_tesla_model_y-pic-3936141801191104405-1024x768.jpeg)\' title=\'used 2021 Tesla Model Y Long Range White 5YJYGDEE7MF095836\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2021 Tesla Model Y Long Range</div>\n<div class=\'subtext\'>\n15,357 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$65,950</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $951/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EB4LF650017"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--odH4v3Ac--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-6641217372375928096-1024x768.jpeg)\' title=\'used 2020 Tesla Model 3 Long Range White 5YJ3E1EB4LF650017\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'badge price_drop\' data-spot=\'1\'>\nPrice Drop\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2020 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n10,645 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$48,650</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $701/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA2JF173091"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.aut ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="74"><a>74</a></li><li data-page="75"><a>75</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %%
# Data to be collected
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1645063349,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEE7MF095836',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEE7MF095836',
#   'clickoff_url': 'https://www.shift.com/car/c1353270?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 237466807,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/09/44/2021_tesla_model_y-pic-3936141801191104405-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--K7bM74lT--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/09/44/2021_tesla_model_y-pic-3936141801191104405-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$65,950',
#   'price_unformatted': 65950,
#   'mileage': '15,357 Miles',
#   'mileage_unformatted': 15357,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJYGDEE7MF095836',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '323643049',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1353270',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1640793845,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB4LF650017',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4LF650017',
#   'clickoff_url': 'https://www.shift.com/car/c1403290?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234321716,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-6641217372375928096-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--odH4v3Ac--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-6641217372375928096-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$48,650',
#   'price_unformatted': 48650,
#   'mileage': '10,645 Miles',
#   'mileage_unformatted': 10645,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB4LF650017',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '320112155',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1403290',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1643559075,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2JF173091',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF173091',
#   'clickoff_url': 'https://www.shift.com/car/c1520451?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 236373664,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/11/40/2018_tesla_model_3-pic-5349695668134513161-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9hJO_698--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/11/40/2018_tesla_model_3-pic-5349695668134513161-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$43,150',
#   'price_unformatted': 43150,
#   'mileage': '35,559 Miles',
#   'mileage_unformatted': 35559,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2JF173091',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '322393597',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1520451',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Mid Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642176600,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB9KF511760',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB9KF511760',
#   'clickoff_url': 'https://www.shift.com/car/c1272784?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235304456,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2019_tesla_model_3-pic-7915060487973289895-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5tH1Y228--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2019_tesla_model_3-pic-7915060487973289895-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$46,300',
#   'price_unformatted': 46300,
#   'mileage': '28,890 Miles',
#   'mileage_unformatted': 28890,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB9KF511760',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '321203974',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1272784',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641347716,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EBXLF650345',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXLF650345',
#   'clickoff_url': 'https://www.shift.com/car/c162764?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234690633,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-3797232775774187303-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hDfjik8G--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2020_tesla_model_3-pic-3797232775774187303-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$48,950',
#   'price_unformatted': 48950,
#   'mileage': '5,616 Miles',
#   'mileage_unformatted': 5616,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EBXLF650345',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '320503319',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c162764',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1644112806,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA5JF021452',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA5JF021452',
#   'clickoff_url': 'https://www.shift.com/car/c188352?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 236795354,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/18/13/31/2018_tesla_model_3-pic-7844540094270580836-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--nAxYQr6X--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/18/13/31/2018_tesla_model_3-pic-7844540094270580836-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$44,300',
#   'price_unformatted': 44300,
#   'mileage': '25,355 Miles',
#   'mileage_unformatted': 25355,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA5JF021452',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '322882081',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c188352',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642817179,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6JF053892',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF053892',
#   'clickoff_url': 'https://www.shift.com/car/c195777?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235784316,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2018_tesla_model_3-pic-5257318785289483526-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--sdEspXWC--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2018_tesla_model_3-pic-5257318785289483526-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$39,950',
#   'price_unformatted': 39950,
#   'mileage': '56,823 Miles',
#   'mileage_unformatted': 56823,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA6JF053892',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '321729854',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c195777',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642009757,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8JF061217',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF061217',
#   'clickoff_url': 'https://www.berkshirehathawayautomotive.com/catcher.esl?vin=5YJ3E1EA8JF061217&atc_ownerid=autolist&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235154879,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/13/07/34/2018_tesla_model_3-pic-1708959278347123645-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--geKhe1mO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/13/07/34/2018_tesla_model_3-pic-1708959278347123645-1024x768.jpeg',
#   'lat': 37.6732,
#   'lon': -122.463,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$45,493',
#   'price_unformatted': 45493,
#   'mileage': '17,885 Miles',
#   'mileage_unformatted': 17885,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 7,
#   'dealer_name': 'Serramonte Ford',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA8JF061217',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '321025677',
#    'remote_dealer_id': '55246',
#    'dealer_name': 'Serramonte Ford',
#    'remote_sku': 'P4646',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'serramonte_ford',
#    'dealer_uuid': 'c89730bc-a118-49cb-a50b-09c4ad611540',
#    'dealer_group_unique_name': 'berkshire_hathaway_automotive_car_gurus',
#    'dealer_group_uuid': '6edd5326-1c9f-408d-918f-8cb1cd0e2f01'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 229,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641015253,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2KF301508',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF301508',
#   'clickoff_url': 'https://www.carmax.com/car/21915924?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234532173,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21915924/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0xlfPyHw--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21915924/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.69056829597337,
#   'lon': -122.4466776578749,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$45,998',
#   'price_unformatted': 45998,
#   'mileage': '25,139 Miles',
#   'mileage_unformatted': 25139,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2KF301508',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA2KF301508',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '21915924',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1643386211,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8JF059211',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF059211',
#   'clickoff_url': 'https://www.shift.com/car/c1419320?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 236226684,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/37/2018_tesla_model_3-pic-9119826179625542533-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Sj-EcbP4--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/37/2018_tesla_model_3-pic-9119826179625542533-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$42,350',
#   'price_unformatted': 42350,
#   'mileage': '39,643 Miles',
#   'mileage_unformatted': 39643,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA8JF059211',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '322243387',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1419320',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1635959165,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6JF010623',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF010623',
#   'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJ3E1EA6JF010623&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 230794948,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/18/00/42/2018_tesla_model_3-pic-7240699439564966012-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--KN7Xnkd---/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/18/00/42/2018_tesla_model_3-pic-7240699439564966012-1024x768.jpeg',
#   'lat': 38.4108,
#   'lon': -122.719,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$45,577',
#   'price_unformatted': 45577,
#   'mileage': '35,118 Miles',
#   'mileage_unformatted': 35118,
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'Lithia Chrysler Jeep Dodge Of Santa Rosa',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA6JF010623',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '316091162',
#    'remote_dealer_id': '60398',
#    'dealer_name': 'Lithia Chrysler Jeep Dodge of Santa Rosa',
#    'remote_sku': 'JF010623',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'lithia_chrysler_jeep_dodgeof_santa_rosa',
#    'dealer_uuid': '854da0e9-8c99-480f-a288-6a3905318ae0',
#    'dealer_group_unique_name': 'lithia_cargurus',
#    'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 229,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1644024604,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA0MF001422',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0MF001422',
#   'clickoff_url': 'https://www.carmax.com/car/21669423?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 236729090,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21669423/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tA-sZLSi--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21669423/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 38.27872113250454,
#   'lon': -122.0043812304184,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$50,998',
#   'price_unformatted': 50998,
#   'mileage': '3,342 Miles',
#   'mileage_unformatted': 3342,
#   'city': 'Fairfield',
#   'state': 'CA',
#   'distance_from_origin': 41,
#   'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA0MF001422',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA0MF001422',
#    'remote_dealer_id': '6048',
#    'dealer_name': 'CarMax Fairfield',
#    'remote_sku': '21669423',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fairfield',
#    'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1645114451,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB7KF387794',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7KF387794',
#   'clickoff_url': 'https://www.shift.com/car/c130527?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 237506693,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/17/01/15/2019_tesla_model_3-pic-3566458169498854992-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--s8W_cxoO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/17/01/15/2019_tesla_model_3-pic-3566458169498854992-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$47,950',
#   'price_unformatted': 47950,
#   'mileage': '39,849 Miles',
#   'mileage_unformatted': 39849,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB7KF387794',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '323677089',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c130527',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642052722,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E47JF263600',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E47JF263600',
#   'clickoff_url': 'https://www.carmax.com/car/21359590?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235194108,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21359590/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--BxM2JJml--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21359590/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.69056829597337,
#   'lon': -122.4466776578749,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$82,998',
#   'price_unformatted': 82998,
#   'mileage': '29,792 Miles',
#   'mileage_unformatted': 29792,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJSA1E47JF263600',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJSA1E47JF263600',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '21359590',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'P100D',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1643126974,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA9LF808097',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA9LF808097',
#   'clickoff_url': 'https://www.carmax.com/car/22101530?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235965535,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22101530/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4AZtUTNy--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22101530/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.69056829597337,
#   'lon': -122.4466776578749,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$44,998',
#   'price_unformatted': 44998,
#   'mileage': '29,579 Miles',
#   'mileage_unformatted': 29579,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA9LF808097',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA9LF808097',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '22101530',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1643220039,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB0JF132533',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB0JF132533',
#   'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJ3E1EB0JF132533&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 236072232,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/09/01/28/2018_tesla_model_3-pic-2872840234416838499-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--QblbS7a8--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/09/01/28/2018_tesla_model_3-pic-2872840234416838499-1024x768.jpeg',
#   'lat': 38.4108,
#   'lon': -122.719,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$44,721',
#   'price_unformatted': 44721,
#   'mileage': '51,372 Miles',
#   'mileage_unformatted': 51372,
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'Lithia Chrysler Jeep Dodge Of Santa Rosa',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB0JF132533',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '322045837',
#    'remote_dealer_id': '60398',
#    'dealer_name': 'Lithia Chrysler Jeep Dodge of Santa Rosa',
#    'remote_sku': 'JF132533',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'lithia_chrysler_jeep_dodgeof_santa_rosa',
#    'dealer_uuid': '854da0e9-8c99-480f-a288-6a3905318ae0',
#    'dealer_group_unique_name': 'lithia_cargurus',
#    'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 229,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1645063349,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB1LF628654',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB1LF628654',
#   'clickoff_url': 'https://www.shift.com/car/c154612?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 237466804,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/37/2020_tesla_model_3-pic-1975125474396053237-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--FsiAzq8a--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/37/2020_tesla_model_3-pic-1975125474396053237-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$52,950',
#   'price_unformatted': 52950,
#   'mileage': '11,614 Miles',
#   'mileage_unformatted': 11614,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB1LF628654',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '323643045',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c154612',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1643818164,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEEXMF187815',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEEXMF187815',
#   'clickoff_url': 'https://www.shift.com/car/c111679?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 236537076,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/10/14/2021_tesla_model_y-pic-4665260296460361596-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--u5oYZ-LK--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/10/14/2021_tesla_model_y-pic-4665260296460361596-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$63,950',
#   'price_unformatted': 63950,
#   'mileage': '8,950 Miles',
#   'mileage_unformatted': 8950,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJYGDEEXMF187815',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '320932984',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c111679',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1643854241,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB8LF647895',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8LF647895',
#   'clickoff_url': 'https://www.shift.com/car/c177818?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 236587326,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/16/12/39/2020_tesla_model_3-pic-8319363011430771450-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qGmPIrm1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/16/12/39/2020_tesla_model_3-pic-8319363011430771450-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$49,950',
#   'price_unformatted': 49950,
#   'mileage': '16,761 Miles',
#   'mileage_unformatted': 16761,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB8LF647895',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '322634336',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c177818',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1644942506,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E42FF105222',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E42FF105222',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 237350389,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/02/14/22/18/2015_tesla_model_s-pic-5088634327951041336-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--zb7sK_jO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/02/14/22/18/2015_tesla_model_s-pic-5088634327951041336-1024x768.jpeg',
#   'lat': 37.6612,
#   'lon': -122.075,
#   'year': 2015,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$55,991',
#   'price_unformatted': 55991,
#   'mileage': '36,459 Miles',
#   'mileage_unformatted': 36459,
#   'city': 'Hayward',
#   'state': 'CA',
#   'distance_from_origin': 20,
#   'dealer_name': 'AutoNation Toyota Hayward',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJSA1E42FF105222',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '323512089',
#    'remote_dealer_id': '288154',
#    'dealer_name': 'AutoNation Toyota Hayward',
#    'remote_sku': 'FF105222',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'autonation_toyota_hayward',
#    'dealer_uuid': '2cf0bdbe-9dca-454f-bb9a-7f0522880c1c',
#    'dealer_group_unique_name': 'autonation_cargurus',
#    'dealer_group_uuid': '50f624ea-bcec-433b-b6a8-8fa8086d7ab7'},
#   'trim': 'P85D',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False}]

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# model 
results_json['search_results'][0]['model']
# Out:
# 'Model Y'

# %%
# mileage
results_json['search_results'][0]['mileage']
# Out:
# '15,357 Miles'

# %%
# year
results_json['search_results'][0]['year']
# Out:
# 2021

# %%
# dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'Shift SF - Test Drives Delivered To You'

# %%
# price
results_json['search_results'][0]['price']
# Out:
# '$65,950'

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_items:
    
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['mileage'])
    
    # year
    year.append(result['year']) 
    
    # dealer name
    dealer_name.append(result['dealer_name']) 
    
    # price
    price.append(result['price'])

# %%
tesla_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_df
# Out:
#       Model       Mileage  Year  \
# 0   Model Y  15,357 Miles  2021
# 1   Model 3  10,645 Miles  2020
# 2   Model 3  35,559 Miles  2018
# 3   Model 3  28,890 Miles  2019
# 4   Model 3   5,616 Miles  2020
# 5   Model 3  25,355 Miles  2018
# 6   Model 3  56,823 Miles  2018
# 7   Model 3  17,885 Miles  2018
# 8   Model 3  25,139 Miles  2019
# 9   Model 3  39,643 Miles  2018
# 10  Model 3  35,118 Miles  2018
# 11  Model 3   3,342 Miles  2021
# 12  Model 3  39,849 Miles  2019
# 13  Model S  29,792 Miles  2018
# 14  Model 3  29,579 Miles  2020
# 15  Model 3  51,372 Miles  2018
# 16  Model 3  11,614 Miles  2020
# 17  Model Y   8,950 Miles  2021
# 18  Model 3  16,761 Miles  2020
# 19  Model S  36,459 Miles  2015
#
#                                           Dealer Name    Price
# 0             Shift SF - Test Drives Delivered To You  $65,950
# 1             Shift SF - Test Drives Delivered To You  $48,650
# 2             Shift SF - Test Drives Delivered To You  $43,150
# 3             Shift SF - Test Drives Delivered To You  $46,300
# 4             Shift SF - Test Drives Delivered To You  $48,950
# 5             Shift SF - Test Drives Delivered To You  $44,300
# 6             Shift SF - Test Drives Delivered To You  $39,950
# 7                                     Serramonte Ford  $45,493
# 8                        CarMax Serramonte - Now Open  $45,998
# 9             Shift SF - Test Drives Delivered To You  $42,350
# 10           Lithia Chrysler Jeep Dodge Of Santa Rosa  $45,577
# 11  CarMax Fairfield - Now Offering Curbside Picku...  $50,998
# 12            Shift SF - Test Drives Delivered To You  $47,950
# 13                       CarMax Serramonte - Now Open  $82,998
# 14                       CarMax Serramonte - Now Open  $44,998
# 15           Lithia Chrysler Jeep Dodge Of Santa Rosa  $44,721
# 16            Shift SF - Test Drives Delivered To You  $52,950
# 17            Shift SF - Test Drives Delivered To You  $63,950
# 18            Shift SF - Test Drives Delivered To You  $49,950
# 19                          AutoNation Toyota Hayward  $55,991

# %% [markdown]
# # Scraping 5 pages

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}


model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1,6):

    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    # response variable for the get request
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (20 items for each page)
    result_items = results_json['search_results']
    
    for result in result_items:
    
        # model
        model.append(result['model'])

        # mileage
        mileage.append(result['mileage'])

        # year
        year.append(result['year']) 

        # dealer name
        dealer_name.append(result['dealer_name']) 

        # price
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_multiple_df
# Out:
#       Model       Mileage  Year                              Dealer Name  \
# 0   Model Y  15,357 Miles  2021  Shift SF - Test Drives Delivered To You
# 1   Model 3  10,645 Miles  2020  Shift SF - Test Drives Delivered To You
# 2   Model 3  35,559 Miles  2018  Shift SF - Test Drives Delivered To You
# 3   Model 3  28,890 Miles  2019  Shift SF - Test Drives Delivered To You
# 4   Model 3   5,616 Miles  2020  Shift SF - Test Drives Delivered To You
# ..      ...           ...   ...                                      ...
# 95  Model S  62,965 Miles  2017  Shift SF - Test Drives Delivered To You
# 96  Model 3  14,410 Miles  2019          CarMax Pleasant Hill - Now Open
# 97  Model 3   6,498 Miles  2021             CarMax Serramonte - Now Open
# 98  Model S  46,420 Miles  2018           Mercedes-Benz Of Stevens Creek
# 99  Model 3  12,250 Miles  2020          CarMax Pleasant Hill - Now Open
#
#       Price
# 0   $65,950
# 1   $48,650
# 2   $43,150
# 3   $46,300
# 4   $48,950
# ..      ...
# 95  $56,950
# 96  $45,998
# 97  $48,998
# 98  $64,690
# 99  $55,998
#
# [100 rows x 5 columns]

# %% [markdown]
# # Storing in Excel

# %%
tesla_multiple_df.to_excel('cardata.xlsx', index=False)
